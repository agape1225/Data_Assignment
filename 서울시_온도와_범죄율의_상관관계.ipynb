# %% [markdown]
# <a href="https://colab.research.google.com/github/agape1225/Data_Assignment/blob/main/%EC%84%9C%EC%9A%B8%EC%8B%9C_%EC%98%A8%EB%8F%84%EC%99%80_%EB%B2%94%EC%A3%84%EC%9C%A8%EC%9D%98_%EC%83%81%EA%B4%80%EA%B4%80%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv

seoul_crime_statistics = pd.read_csv('201904055.csv', encoding='utf-8-sig', low_memory=False, quoting=csv.QUOTE_NONE)

#서울시의 온도와 범죄율 데이터
seoul_crime_statistics.head(20)
# Out:
#         일시  평균기온(℃)  평균최고기온(℃)  최고기온(℃)      최고기온일자  평균최저기온(℃)  최저기온(℃)  \
# 0   08-Jan     -1.7        1.9      7.3  2008-01-06       -5.0    -11.1
# 1   08-Feb     -1.2        3.2     10.5  2008-02-22       -4.9    -10.1
# 2   08-Mar      7.3       11.9     19.8  2008-03-21        3.7     -1.7
# 3   08-Apr     14.1       19.5     28.0  2008-04-19        9.3      3.8
# 4   08-May     17.7       22.7     28.5  2008-05-29       13.1      8.1
# 5   08-Jun     21.5       26.1     29.6  2008-06-20       17.6     13.7
# 6   08-Jul     25.1       28.4     32.9  2008-07-09       22.6     20.2
# 7   08-Aug     25.3       29.5     35.4  2008-08-08       21.8     16.3
# 8   08-Sep     22.0       26.9     32.0  2008-09-17       18.0     10.3
# 9   08-Oct     16.1       21.0     28.3  2008-10-18       12.1      5.6
# 10  08-Nov      7.6       11.7     18.4  2008-11-06        3.8     -7.2
# 11  08-Dec      1.1        5.0     13.3  2008-12-10       -2.7    -13.1
# 12  09-Jan     -2.0        2.3     12.2  2009-01-30       -5.5    -11.4
# 13  09-Feb      2.9        6.8     16.1  2009-02-13       -0.6     -8.6
# 14  09-Mar      6.0       10.6     22.2  2009-03-21        1.8     -3.3
# 15  09-Apr     12.7       18.0     25.8  2009-04-19        8.1      2.2
# 16  09-May     19.1       24.3     31.0  2009-05-28       14.6      9.8
# 17  09-Jun     22.4       26.7     32.4  2009-06-27       18.8     14.3
# 18  09-Jul     24.3       28.2     32.4  2009-07-16       21.0     18.7
# 19  09-Aug     25.7       29.5     34.4  2009-08-16       22.4     16.4
#
#         최저기온일자        합계 발생     살인 발생      강도 발생 강간.강제추행 발생       절도 발생  \
# 0   2008-01-17   """7663"""  """19"""   """49"""  """191"""  """1870"""
# 1   2008-02-13   """6503"""   """9"""   """43"""  """184"""  """1733"""
# 2   2008-03-05   """8418"""  """14"""   """78"""  """262"""  """2374"""
# 3   2008-04-04   """8990"""  """19"""  """102"""  """276"""  """2513"""
# 4   2008-05-14   """9232"""  """23"""   """79"""  """297"""  """2406"""
# 5   2008-06-05  """10329"""  """19"""   """95"""  """364"""  """2893"""
# 6   2008-07-01   """9804"""  """15"""   """90"""  """331"""  """2577"""
# 7   2008-08-22   """8754"""  """19"""   """69"""  """327"""  """2316"""
# 8   2008-09-27  """10134"""  """22"""   """90"""  """342"""  """2701"""
# 9   2008-10-28   """9950"""  """18"""   """92"""  """313"""  """2620"""
# 10  2008-11-19   """8607"""  """19"""   """73"""  """257"""  """2387"""
# 11  2008-12-06   """9387"""  """25"""   """88"""  """277"""  """2504"""
# 12  2009-01-24   """7307"""  """18"""   """93"""  """214"""  """1901"""
# 13  2009-02-17   """7271"""  """11"""   """66"""  """205"""  """1870"""
# 14  2009-03-14   """9863"""  """18"""  """121"""  """279"""  """2913"""
# 15  2009-04-01   """9618"""  """16"""  """128"""  """281"""  """2662"""
# 16  2009-05-05  """11473"""  """29"""  """288"""  """340"""  """3767"""
# 17  2009-06-01  """11386"""  """25"""  """127"""  """378"""  """3397"""
# 18  2009-07-10  """11525"""  """20"""  """150"""  """363"""  """4122"""
# 19  2009-08-31   """9377"""  """34"""  """104"""  """371"""  """3324"""
#
#          폭력 발생
# 0   """5534"""
# 1   """4534"""
# 2   """5690"""
# 3   """6080"""
# 4   """6427"""
# 5   """6958"""
# 6   """6791"""
# 7   """6023"""
# 8   """6979"""
# 9   """6907"""
# 10  """5871"""
# 11  """6493"""
# 12  """5081"""
# 13  """5119"""
# 14  """6532"""
# 15  """6531"""
# 16  """7049"""
# 17  """7459"""
# 18  """6870"""
# 19  """5544"""

# %% [markdown]
# 데이터를 비교해야 해서 하나의 피겨에 여러개의 선을 그려야합니다.

# %%
import matplotlib.pyplot as plt

col_list = seoul_crime_statistics["일시"].values.tolist()
tem = seoul_crime_statistics["평균기온(℃)"].values.tolist()
print(col_list)
print(tem)
# Out:
# ['08-Jan', '08-Feb', '08-Mar', '08-Apr', '08-May', '08-Jun', '08-Jul', '08-Aug', '08-Sep', '08-Oct', '08-Nov', '08-Dec', '09-Jan', '09-Feb', '09-Mar', '09-Apr', '09-May', '09-Jun', '09-Jul', '09-Aug', '09-Sep', '09-Oct', '09-Nov', '09-Dec', '10-Jan', '10-Feb', '10-Mar', '10-Apr', '10-May', '10-Jun', '10-Jul', '10-Aug', '10-Sep', '10-Oct', '10-Nov', '10-Dec', '11-Jan', '11-Feb', '11-Mar', '11-Apr', '11-May', '11-Jun', '11-Jul', '11-Aug', '11-Sep', '11-Oct', '11-Nov', '11-Dec', '12-Jan', '12-Feb', '12-Mar', '12-Apr', '12-May', '12-Jun', '12-Jul', '12-Aug', '12-Sep', '12-Oct', '12-Nov', '12-Dec', '13-Jan', '13-Feb', '13-Mar', '13-Apr', '13-May', '13-Jun', '13-Jul', '13-Aug', '13-Sep', '13-Oct', '13-Nov', '13-Dec']
# [-1.7, -1.2, 7.3, 14.1, 17.7, 21.5, 25.1, 25.3, 22.0, 16.1, 7.6, 1.1, -2.0, 2.9, 6.0, 12.7, 19.1, 22.4, 24.3, 25.7, 21.8, 16.0, 6.9, -1.0, -4.5, 1.4, 4.3, 9.5, 17.2, 23.4, 25.8, 26.5, 21.8, 14.5, 6.5, -1.3, -7.2, 1.2, 3.6, 10.7, 17.9, 22.0, 24.6, 25.8, 21.8, 14.2, 10.7, -0.9, -2.8, -2.0, 5.1, 12.3, 19.7, 24.1, 25.4, 27.1, 21.0, 15.3, 5.5, -4.1, -3.4, -1.2, 5.1, 10.0, 18.2, 24.4, 25.5, 27.7, 21.8, 15.8, 6.2, -0.2]

# %%
fig, ax = plt.subplots(figsize=(60,20))
ax.plot(col_list, tem)
ax.set_title("seoul temp")
ax.legend()
fig.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import re

crime_sum = seoul_crime_statistics["합계 발생"].values.tolist()
crime_sum = [re.sub(r'[^0-9]', '', str(elem)) for elem in crime_sum]
crime_sum = list(map(int, crime_sum))

murder = seoul_crime_statistics["살인 발생"].values.tolist()
murder = [re.sub(r'[^0-9]', '', str(elem)) for elem in murder]
murder = list(map(int, murder))

robbery = seoul_crime_statistics["강도 발생"].values.tolist()
robbery = [re.sub(r'[^0-9]', '', str(elem)) for elem in robbery]
robbery = list(map(int, robbery))

rape = seoul_crime_statistics["강간.강제추행 발생"].values.tolist()
rape = [re.sub(r'[^0-9]', '', str(elem)) for elem in rape]
rape = list(map(int, rape))

theft = seoul_crime_statistics["절도 발생"].values.tolist()
theft = [re.sub(r'[^0-9]', '', str(elem)) for elem in theft]
theft = list(map(int, theft))

violence = seoul_crime_statistics["폭력 발생"].values.tolist()
violence = [re.sub(r'[^0-9]', '', str(elem)) for elem in violence]
violence = list(map(int, violence))

# %%
fig, ax = plt.subplots(figsize=(60,20))
#ax.plot(col_list, crime_sum, label="crime_sum")
ax.plot(col_list, murder, label="murder")
ax.plot(col_list, robbery, label="robbery")
ax.plot(col_list, rape, label="rape")
ax.plot(col_list, theft, label="theft")
ax.plot(col_list, violence, label="violence")

ax.legend()

ax.set_title("seoul crime rate")
fig.show()

# %% [markdown]
# 이렇게 해보니 온도 데이터와는 차이가 너무 나서 정규화 과정을 거치게 되었습니다.

# %%
normaliz_data = seoul_crime_statistics
#필요없는 데이터는 가시성을 위해 삭제하였습니다.

normaliz_data = normaliz_data.drop(["평균최고기온(℃)",	"최고기온(℃)",	
                    "최고기온일자",	"평균최저기온(℃)",	
                    "최저기온(℃)",	"최저기온일자",	"합계 발생"], axis="columns")
normaliz_data.head()
# Out:
#        일시  평균기온(℃)     살인 발생      강도 발생 강간.강제추행 발생       절도 발생       폭력 발생
# 0  08-Jan     -1.7  """19"""   """49"""  """191"""  """1870"""  """5534"""
# 1  08-Feb     -1.2   """9"""   """43"""  """184"""  """1733"""  """4534"""
# 2  08-Mar      7.3  """14"""   """78"""  """262"""  """2374"""  """5690"""
# 3  08-Apr     14.1  """19"""  """102"""  """276"""  """2513"""  """6080"""
# 4  08-May     17.7  """23"""   """79"""  """297"""  """2406"""  """6427"""

# %%
normaliz_data = normaliz_data.set_index("일시")

normaliz_data.head()
# Out:
#         평균기온(℃)     살인 발생      강도 발생 강간.강제추행 발생       절도 발생       폭력 발생
# 일시
# 08-Jan     -1.7  """19"""   """49"""  """191"""  """1870"""  """5534"""
# 08-Feb     -1.2   """9"""   """43"""  """184"""  """1733"""  """4534"""
# 08-Mar      7.3  """14"""   """78"""  """262"""  """2374"""  """5690"""
# 08-Apr     14.1  """19"""  """102"""  """276"""  """2513"""  """6080"""
# 08-May     17.7  """23"""   """79"""  """297"""  """2406"""  """6427"""

# %%
def apply_formula(value):
    value = re.sub(r'[^0-9]', '', str(value))
    value = int(value)
    return value

normaliz_data.iloc[:, 1:6] = normaliz_data.iloc[:, 1:6].applymap(apply_formula)

normaliz_data.head()
# Out:
# <ipython-input-23-2169a10a5770>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   normaliz_data.iloc[:, 1:6] = normaliz_data.iloc[:, 1:6].applymap(apply_formula)
#         평균기온(℃)  살인 발생  강도 발생  강간.강제추행 발생  절도 발생  폭력 발생
# 일시
# 08-Jan     -1.7     19     49         191   1870   5534
# 08-Feb     -1.2      9     43         184   1733   4534
# 08-Mar      7.3     14     78         262   2374   5690
# 08-Apr     14.1     19    102         276   2513   6080
# 08-May     17.7     23     79         297   2406   6427
